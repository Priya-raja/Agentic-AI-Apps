# %%
# %pip uninstall dotenv
# Out:
# Found existing installation: dotenv 0.9.9
# Uninstalling dotenv-0.9.9:
#   Would remove:
#     /Users/priyaraja/Library/Python/3.9/lib/python/site-packages/dotenv-0.9.9.dist-info/*
# Proceed (Y/n)? ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openai_agents
# Out:
# Collecting openai_agents
#   Downloading openai_agents-0.6.1-py3-none-any.whl.metadata (13 kB)
# Collecting griffe<2,>=1.5.6 (from openai_agents)
#   Downloading griffe-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: mcp<2,>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai_agents) (1.16.0)
# Collecting openai<3,>=2.8.0 (from openai_agents)
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting pydantic<3,>=2.12.3 (from openai_agents)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: requests<3,>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai_agents) (2.32.5)
# Collecting types-requests<3,>=2.0 (from openai_agents)
#   Downloading types_requests-2.32.4.20250913-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai_agents) (4.15.0)
# Collecting colorama>=0.4 (from griffe<2,>=1.5.6->openai_agents)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio>=4.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (0.4.1)
# Requirement already satisfied: httpx>=0.27.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai_agents) (0.37.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai<3,>=2.8.0->openai_agents) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai<3,>=2.8.0->openai_agents) (0.11.1)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai<3,>=2.8.0->openai_agents) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai<3,>=2.8.0->openai_agents) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai_agents) (3.10)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai_agents) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai_agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai_agents) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=2.12.3->openai_agents) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2.12.3->openai_agents)
#   Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=2.12.3->openai_agents) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.0->openai_agents) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.0->openai_agents) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai_agents) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai_agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai_agents) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai_agents) (0.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.11.0->openai_agents) (1.1.1)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.11.0->openai_agents) (8.3.0)
# Downloading openai_agents-0.6.1-py3-none-any.whl (237 kB)
# Downloading griffe-1.15.0-py3-none-any.whl (150 kB)
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.9 MB/s  0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.8 MB/s  0:00:00
# Downloading types_requests-2.32.4.20250913-py3-none-any.whl (20 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: types-requests, pydantic-core, colorama, pydantic, griffe, openai, openai_agents
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.9
#     Uninstalling pydantic-2.11.9:
#       Successfully uninstalled pydantic-2.11.9
#   Attempting uninstall: openai╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pydantic]
#     Found existing installation: openai 2.7.1━━━━━━━━━━━━━━━━━ 3/7 [pydantic]
#     Uninstalling openai-2.7.1:╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pydantic]
#       Successfully uninstalled openai-2.7.1━━━━━━━━━━━━━━━━━━━ 3/7 [pydantic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [openai_agents]0m [openai]
# Successfully installed colorama-0.4.6 griffe-1.15.0 openai-2.8.1 openai_agents-0.6.1 pydantic-2.12.5 pydantic-core-2.41.5 types-requests-2.32.4.20250913
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from agents import Agent, trace, Runner

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
agent
# Out:
# Agent(name='Jokester', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a joke teller', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent,"Tell a joke about Apple")
    print(result.final_output)
# Out:
# RunResult:
# - Last agent: Agent(name="Jokester", ...)
# - Final output (str):
#     Why did the apple stop in the middle of the road?
#
#     Because it ran out of juice! 🍏😂
# - 1 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)
